# %% [markdown]
# # TissUUmaps Jupyter integration
#
# ### Install TissUUmaps via pip

# %%
# Make sure libvips is installed on your computer:
#!apt install libvips
# !pip install TissUUmaps --upgrade

# %% [markdown]
# ### Load tissuumaps juptyer module

# %%
import tissuumaps.jupyter as tj

# %% [markdown]
# ### Display images and markers in TissUUmaps

# %%
imageFiles = [
    "./data/breast/breastcancerHE.png",
    "./data/breast/breastcancerFluo.png"
]

csvFiles = [
    "./data/breast/breastcancer.csv"
]

# Load images and csv files with some marker parameters:
tj.loaddata(imageFiles, csvFiles, xSelector="global_X_pos", ySelector="global_Y_pos",
        keySelector="letters", nameSelector="gene_name",
        scaleSelector="global_Y_pos", colormap="interpolateOranges", 
        boundingBox=[0.0,0.0,0.1,0.1], scaleFactor=0.001, 
        height=400, tmapFilename="mainProject")

# Load images only:
tj.loaddata(imageFiles, height=400)

# Load markers only:
tj.loaddata([],csvFiles, xSelector="global_X_pos", ySelector="global_Y_pos", keySelector="letters", height=400)

# %% [markdown]
# Creating project file C:\Users\chrav452\Documents\datatest_tissuumaps\breast\mainProject.tmap
# ![image-2.png](attachment:image-2.png)
#
# Creating project file C:\Users\chrav452\Documents\datatest_tissuumaps\breast\_project.tmap
# ![image-3.png](attachment:image-3.png)
#
# Creating project file C:\Users\chrav452\Documents\datatest_tissuumaps\breast\_project.tmap
# ![image-4.png](attachment:image-4.png)

# %%
# Load a tmap project file:
tj.opentmap("./data/breast/mainProject.tmap", height=400)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Load a single image with opentmap:
tj.opentmap("./data/breast/breastcancerHE.png",height=400)

# %% [markdown]
# ![image.png](attachment:image.png)
